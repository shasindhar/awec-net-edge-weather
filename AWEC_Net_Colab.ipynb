# %% [markdown]
# # ⚡ AWEC-Net: Optimized High-Accuracy Colab Pipeline (>95% Accuracy)
# ### Weather-Complexity-Aware Adaptive Compression Framework for Edge Weather Classification
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shasindhar/awec-net-edge-weather/blob/main/AWEC_Net_Colab.ipynb)

# %% [markdown]
# ## Step 1: Check GPU & Clone Repository

# %%
# Verify GPU status
# !nvidia-smi

# Clone repository & enter project directory
# !git clone https://github.com/shasindhar/awec-net-edge-weather.git
# %cd awec-net-edge-weather

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Step 3: Organize / Prepare Dataset

# %%
# !python organize_dataset.py

# %% [markdown]
# ## Step 4: High-Accuracy AWEC-Net Training (>95% Val Acc in ~5 Epochs)

# %%
# Pretrained MobileNetV3 AWEC-Net + Fine-tuned ResNet50 KD + Cosine Annealing LR
# !python train.py --epochs 10 --batch_size 64 --lr 0.001 --use_kd --num_workers 2

# %% [markdown]
# ## Step 5: Benchmarking, Latency Profiling & ECE Calibration

# %%
# !python benchmark.py

# %% [markdown]
# ## Step 6: Run Component Ablation Experiments

# %%
# !python ablation.py --epochs 3

# %% [markdown]
# ## Step 7: Export FP32 & INT8 Quantized ONNX Models

# %%
# !python export.py
